# %%
import pandas as pd

# %%
dfs = pd.read_excel("4-abril-2025.xlsx", sheet_name="30-04", header=1)
dfs
# Out:
#     N° de ordem  N° de ordem.1                              PACIENTE  \
# 0           NaN           21.0       MARIA DAS DORES BATISTA XAVIER
# 1          21.0           11.0         ARISTOR LAURENTINO DE ARAUJO
# 2          32.0           11.0        VANESSA PEREIRA DO NASCIMENTO
# 3          43.0           12.0            DEVENISE MARIA DE SANTANA
# 4          55.0           16.0           IRENE MARIA DA SILVA ANDRE
# 5          71.0           15.0         ROSIANE EUFRASINIA DE LIMA B.
# 6          86.0            6.0                ALICE GADELHA DE SOUZA
# 7          92.0           11.0        DANDARA BEATRIZ DA S. ANDRADE
# 8         103.0           15.0               LUCIANA MATIAS BARBOSA
# 9         118.0           10.0  TALITA PATRICIA DR ANDRANDE MARQUES
# 10        128.0           17.0       JOYCE SUELANE BARBOSA DA SILVA
# 11        145.0           15.0        AYLA VALETHYNA BARBOSA DA CRUZ
# 12        160.0           15.0      PALOMA BEATRIZ PEREIRA DA SILVA
# ...

# %%
new_row = {
    "PACIENTE": "Jose Gomes",
    "P. FEZES": 1,
    "N° de ordem": 1000
    }
dfs = pd.concat([dfs, pd.DataFrame([new_row])], ignore_index=True)

# %%
dfs
# Out:
#     N° de ordem  N° de ordem.1                              PACIENTE  \
# 0           NaN           21.0       MARIA DAS DORES BATISTA XAVIER
# 1          21.0           11.0         ARISTOR LAURENTINO DE ARAUJO
# 2          32.0           11.0        VANESSA PEREIRA DO NASCIMENTO
# 3          43.0           12.0            DEVENISE MARIA DE SANTANA
# 4          55.0           16.0           IRENE MARIA DA SILVA ANDRE
# 5          71.0           15.0         ROSIANE EUFRASINIA DE LIMA B.
# 6          86.0            6.0                ALICE GADELHA DE SOUZA
# 7          92.0           11.0        DANDARA BEATRIZ DA S. ANDRADE
# 8         103.0           15.0               LUCIANA MATIAS BARBOSA
# 9         118.0           10.0  TALITA PATRICIA DR ANDRANDE MARQUES
# 10        128.0           17.0       JOYCE SUELANE BARBOSA DA SILVA
# 11        145.0           15.0        AYLA VALETHYNA BARBOSA DA CRUZ
# 12        160.0           15.0      PALOMA BEATRIZ PEREIRA DA SILVA
# ...
